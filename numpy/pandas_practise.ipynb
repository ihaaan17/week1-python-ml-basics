# %%
import pandas as pd
import numpy as np

s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101",periods = 6)

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.055907 -0.170845  0.117577  1.287278
# 2013-01-02 -0.456224  0.383533 -1.104471  0.260352
# 2013-01-03  1.317096 -0.415781 -1.205289 -1.238954
# 2013-01-04 -0.803543  0.861997 -0.283508  1.806785
# 2013-01-05 -0.764639  0.498538  1.987944  0.421761
# 2013-01-06  0.331299  0.255592  0.507864 -0.824421

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.055907 -0.170845  0.117577  1.287278
# 2013-01-02 -0.456224  0.383533 -1.104471  0.260352
# 2013-01-03  1.317096 -0.415781 -1.205289 -1.238954
# 2013-01-04 -0.803543  0.861997 -0.283508  1.806785
# 2013-01-05 -0.764639  0.498538  1.987944  0.421761

# %%
df.to_numpy()
# Out:
# array([[-0.05590723, -0.17084529,  0.11757712,  1.2872785 ],
#        [-0.45622432,  0.38353334, -1.10447083,  0.2603523 ],
#        [ 1.31709553, -0.41578134, -1.20528943, -1.23895417],
#        [-0.80354268,  0.86199659, -0.2835078 ,  1.80678468],
#        [-0.76463924,  0.49853835,  1.9879439 ,  0.42176104],
#        [ 0.33129892,  0.25559225,  0.50786417, -0.82442093]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.071987  0.235506  0.003353  0.285467
# std    0.806849  0.463312  1.181233  1.174134
# min   -0.803543 -0.415781 -1.205289 -1.238954
# 25%   -0.687536 -0.064236 -0.899230 -0.553228
# 50%   -0.256066  0.319563 -0.082965  0.341057
# 75%    0.234497  0.469787  0.410292  1.070899
# max    1.317096  0.861997  1.987944  1.806785

# %%
df.sort_index(axis= 1 ,ascending = False)
# Out:
#                    D         C         B         A
# 2013-01-01  1.287278  0.117577 -0.170845 -0.055907
# 2013-01-02  0.260352 -1.104471  0.383533 -0.456224
# 2013-01-03 -1.238954 -1.205289 -0.415781  1.317096
# 2013-01-04  1.806785 -0.283508  0.861997 -0.803543
# 2013-01-05  0.421761  1.987944  0.498538 -0.764639
# 2013-01-06 -0.824421  0.507864  0.255592  0.331299

# %%
df2 = pd.DataFrame(

    {
       "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
 
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df["A"]
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.456224  0.383533 -1.104471  0.260352
# 2013-01-03  1.317096 -0.415781 -1.205289 -1.238954
# 2013-01-04 -0.803543  0.861997 -0.283508  1.806785

# %%
df.loc[dates[0]]
# Out:
# A   -0.055907
# B   -0.170845
# C    0.117577
# D    1.287278
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.iloc[3]
# Out:
# A   -0.803543
# B    0.861997
# C   -0.283508
# D    1.806785
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
data = {
    "name":["SpongeBob","patrick","squidward"],
    "age":[21 ,34 ,78]
}

df1 = pd.DataFrame(data);
df1
# Out:
#         name  age
# 0  SpongeBob   21
# 1    patrick   34
# 2  squidward   78

# %%
df1 = pd.DataFrame(data,index=["emp1","emp2","emp3"])
df1
# Out:
#            name  age
# emp1  SpongeBob   21
# emp2    patrick   34
# emp3  squidward   78

# %%
df1["Job"] = ["doctor","N/A","cook"]
df1
new_row = pd.DataFrame([{
    "name":"Sandy","age":28,"Job":"Engineer"},
    {"name":"Eugene","age":60,"Job":"Manager"}] ,
    index = ["emp4","emp5"])
df = pd.concat([df1,new_row])
df
# Out:
#            name  age       Job
# emp1  SpongeBob   21    doctor
# emp2    patrick   34       N/A
# emp3  squidward   78      cook
# emp4      Sandy   28  Engineer
# emp5     Eugene   60   Manager

# %%
import pandas as pd
# You MUST include 'work/' because that is where the volume is mapped
df = pd.read_csv("work/pokemon.csv")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2 # You MUST include 'work/' because that is where the volume is mapped
# ----> 3 df = pd.read_csv("work/pokemon.csv")
#       4 print(df.head())
#
# ...

# %%
import pandas as pd
# Added 'numpy/' to the path because that's where your list says the files are
df = pd.read_csv("work/numpy/pokemon.csv",index_col="Name")
# print(df["Speed"].to_string())
# print(df.loc["Pikachu":"Blastoise",["Attack"]]
print (df.iloc[0:11])
# Out:
#                            # Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                  1  Grass  Poison    318  45      49       49
# Ivysaur                    2  Grass  Poison    405  60      62       63
# Venusaur                   3  Grass  Poison    525  80      82       83
# VenusaurMega Venusaur      3  Grass  Poison    625  80     100      123
# Charmander                 4   Fire     NaN    309  39      52       43
# Charmeleon                 5   Fire     NaN    405  58      64       58
# Charizard                  6   Fire  Flying    534  78      84       78
# CharizardMega Charizard X  6   Fire  Dragon    634  78     130      111
# CharizardMega Charizard Y  6   Fire  Flying    634  78     104       78
# Squirtle                   7  Water     NaN    314  44      48       65
# Wartortle                  8  Water     NaN    405  59      63       80
#
#                            Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
pokemon = input("Enter a pokemon name")
try :
    print(df.loc[pokemon])
except keyError:
    print("not found")
# Out:
# #                   25
# Type 1        Electric
# Type 2             NaN
# Total              320
# HP                  35
# Attack              55
# Defense             40
# Sp. Atk             50
# Sp. Def             50
# Speed               90
# Generation           1
# Legendary        False
# Name: Pikachu, dtype: object

# %%
tall_pokemon = df[df["Attack"]>150]
print(tall_pokemon)
# Out:
#                            #   Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# PinsirMega Pinsir        127      Bug    Flying    600   65     155      120
# GyaradosMega Gyarados    130    Water      Dark    640   95     155      109
# MewtwoMega Mewtwo X      150  Psychic  Fighting    780  106     190      100
# HeracrossMega Heracross  214      Bug  Fighting    600   80     185      115
# TyranitarMega Tyranitar  248     Rock      Dark    700  100     164      150
# BlazikenMega Blaziken    257     Fire  Fighting    630   80     160       80
# Slaking                  289   Normal       NaN    670  150     160      100
# BanetteMega Banette      354    Ghost       NaN    555   64     165       75
# GroudonPrimal Groudon    383   Ground      Fire    770  100     180      160
# RayquazaMega Rayquaza    384   Dragon    Flying    780  105     180      100
# DeoxysAttack Forme       386  Psychic       NaN    600   50     180       20
# ...

# %% [markdown]
# aggregate functions using pandas

# %%
print(df.mean(numeric_only=True))
# Out:
# #             362.81375
# Total         435.10250
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp. Atk        72.82000
# Sp. Def        71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %%
print(df.sum(numeric_only=True))
# Out:
# #             290251
# Total         348082
# HP             55407
# Attack         63201
# Defense        59074
# Sp. Atk        58256
# Sp. Def        57522
# Speed          54622
# Generation      2659
# Legendary         65
# dtype: int64

# %%
print(df.sum(numeric_only=True))
# Out:
# #             290251
# Total         348082
# HP             55407
# Attack         63201
# Defense        59074
# Sp. Atk        58256
# Sp. Def        57522
# Speed          54622
# Generation      2659
# Legendary         65
# dtype: int64

# %%
print(df.count())
# Out:
# #             800
# Type 1        800
# Type 2        414
# Total         800
# HP            800
# Attack        800
# Defense       800
# Sp. Atk       800
# Sp. Def       800
# Speed         800
# Generation    800
# Legendary     800
# dtype: int64

# %%
print(df["Attack"].mean())
# Out:
# 79.00125

# %%
print(df["Attack"].sum())
# Out:
# 63201

# %%
print(df["Attack"].max())
# Out:
# 190

# %%
group = df.groupby("Type 1")
print(group["Attack"].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 group = df.groupby("Type 1")
#       2 print(group["Attack"].mean())
#
# NameError: name 'df' is not defined
